# %% [markdown]
# # Contents:

# %% [markdown]
# #### Import libraries and establish data frame objects
# #### Fixing an outlier in the prices column
# #### Grouping and aggregating a subset of the dataframe
# #### Creating a loyalty flag for existing customers
# #### Creating a spending flag
# #### Creating an order frequency flag
# #### Crosstabulations
# #### Exporting and saving the dataframe

# %% [markdown]
# # Import libraries and establish data frame objects

# %%
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\Shelb\OneDrive\Documents\CF Coursework\Python Fundamentals for Data Analysts\10-2022 Instacart Basket Analysis'

# %%
df=pd.read_pickle(os.path.join(path,'Data','Prepared Data','11-9_orders_products_merged.pkl'))

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0_x', 'order_id', 'user_id', 'order_number',
#        'order_day_of_week', 'hour_order_placed', 'days_since_prior_order',
#        'new_customer', 'product_id', 'add_to_cart_order', 'reordered',
#        'Unnamed: 0_y', 'product_name', 'aisle_id', 'department_id', 'prices',
#        '_merge', 'price_range', 'busiest_day', 'busiest_days',
#        'busiest_period_of_day'],
#       dtype='object')

# %%
# To create a dataframe without unnamed, _merge, and busiest_day (as opposed to busiest_days) columns 
df_trim=df[['order_id', 'user_id', 'order_number',
       'order_day_of_week', 'hour_order_placed', 'days_since_prior_order',
       'new_customer', 'product_id', 'add_to_cart_order', 'reordered', 'product_name', 'aisle_id', 'department_id', 'prices',
       'price_range', 'busiest_days',
       'busiest_period_of_day']]

# %% [markdown]
# ## Fixing an outlier in the prices column

# %%
# To check for items which cost upward of 100 dollars
df_trim.loc[df_trim['prices']>100]
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 10030345    912404       17            12                  2
# 10030346    603376       17            22                  6
# 10030347   3264360      135             2                  2
# 10030348    892534      135             3                  0
# 10030349    229704      342             8                  1
# ...            ...      ...           ...                ...
# 29166209   2249946   204099            29                  0
# 29166210   2363282   204099            31                  0
# 29166211   3181945   204395            13                  3
# 29166212   2486215   205227             7                  3
# 29166213   2232716   205227            10                  0
#
#           hour_order_placed  days_since_prior_order  new_customer  product_id  \
# 10030345                 14                     5.0         False       21553
# 10030346                 16                     4.0         False       21553
# 10030347                 21                    13.0         False       21553
# 10030348                  8                    12.0         False       21553
# 10030349                 19                    30.0         False       21553
# ...                     ...                     ...           ...         ...
# 29166209                  8                     4.0         False       33664
# 29166210                  9                     2.0         False       33664
# 29166211                 15                     8.0         False       33664
# 29166212                 20                     4.0         False       33664
# 29166213                 11                     4.0         False       33664
#
#           add_to_cart_order  reordered                      product_name  \
# 10030345                  5          0  Lowfat 2% Milkfat Cottage Cheese
# 10030346                  3          1  Lowfat 2% Milkfat Cottage Cheese
# 10030347                  6          0  Lowfat 2% Milkfat Cottage Cheese
# 10030348                  3          1  Lowfat 2% Milkfat Cottage Cheese
# 10030349                  9          0  Lowfat 2% Milkfat Cottage Cheese
# ...                     ...        ...                               ...
# 29166209                  1          0             2 % Reduced Fat  Milk
# 29166210                  1          1             2 % Reduced Fat  Milk
# 29166211                 25          0             2 % Reduced Fat  Milk
# 29166212                  8          0             2 % Reduced Fat  Milk
# 29166213                 23          1             2 % Reduced Fat  Milk
#
#           aisle_id  department_id   prices         price_range  \
# 10030345       108             16  14900.0  High range product
# 10030346       108             16  14900.0  High range product
# 10030347       108             16  14900.0  High range product
# 10030348       108             16  14900.0  High range product
# 10030349       108             16  14900.0  High range product
# ...            ...            ...      ...                 ...
# 29166209        84             16  99999.0  High range product
# 29166210        84             16  99999.0  High range product
# 29166211        84             16  99999.0  High range product
# 29166212        84             16  99999.0  High range product
# 29166213        84             16  99999.0  High range product
#
#             busiest_days busiest_period_of_day
# 10030345  Regularly Busy           Most Orders
# 10030346  Regularly Busy           Most Orders
# 10030347  Regularly Busy        Average Orders
# 10030348     Busiest Day        Average Orders
# 10030349     Busiest Day        Average Orders
# ...                  ...                   ...
# 29166209     Busiest Day        Average Orders
# 29166210     Busiest Day           Most Orders
# 29166211      Least Busy           Most Orders
# 29166212      Least Busy        Average Orders
# 29166213     Busiest Day           Most Orders
#
# [5127 rows x 17 columns]

# %%
# To mark outliers as NaN to remove them from future calculations
df_trim.loc[df_trim['prices']>100,'prices']=np.nan

# %%
df_trim['prices'].max()
# Out:
# 25.0

# %% [markdown]
# # Grouping and aggregating a subset of the dataframe

# %% [markdown]
# ## Subset aggregations

# %%
# To create a subset containing the first 1,000,000 rows of df_trim
df_sub=df_trim[:1000000]

# %%
df_sub.shape
# Out:
# (1000000, 17)

# %%
df_sub.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  hour_order_placed  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices        price_range  \
# 0          0         Soda        77              7     9.0  Mid range product
# 1          1         Soda        77              7     9.0  Mid range product
# 2          1         Soda        77              7     9.0  Mid range product
# 3          1         Soda        77              7     9.0  Mid range product
# 4          1         Soda        77              7     9.0  Mid range product
#
#      busiest_days busiest_period_of_day
# 0  Regularly Busy        Average Orders
# 1      Least Busy        Average Orders
# 2      Least Busy           Most Orders
# 3      Least Busy        Average Orders
# 4      Least Busy           Most Orders

# %%
# To group by the product_name column
df_sub.groupby('product_name')

# %%
# To aggregate to produce a single descriptive statistic for the order_number column and group by department_id
df_sub.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# To produce multiple descriptive statistics for the order_number column and group by department_id
df_sub.groupby('department_id').agg({'order_number':['mean','min','max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ## Whole set aggregations

# %%
# To find the aggregate mean for the order_number column for the whole set, grouped by department_id
df_trim.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### The subset mean of the order_number column for department 16 is quite a bit higher than the whole set mean for that department, and for department 17 the subset mean of the order_number column is quite a bit lower than the whole set mean

# %% [markdown]
# # Creating a loyalty flag for existing customers

# %%
# To transform the order_number column to generate the maximum orders for each user
df_trim['max_order']=df_trim.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_4332\924742914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trim['max_order']=df_trim.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_trim.head(15)
# Out:
#     order_id  user_id  order_number  order_day_of_week  hour_order_placed  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True         196                  1
# 1                     15.0         False         196                  1
# 2                     21.0         False         196                  1
# 3                     29.0         False         196                  1
# 4                     28.0         False         196                  1
# 5                     19.0         False         196                  1
# 6                     20.0         False         196                  1
# 7                     14.0         False         196                  2
# 8                      0.0         False         196                  4
# 9                     30.0         False         196                  1
# 10                     7.0         False         196                  2
# 11                     8.0         False         196                  6
# 12                     7.0         False         196                  1
# 13                     7.0         False         196                  1
# 14                    14.0         False         196                  1
#
#     reordered product_name  aisle_id  department_id  prices  \
# 0           0         Soda        77              7     9.0
# 1           1         Soda        77              7     9.0
# 2           1         Soda        77              7     9.0
# 3           1         Soda        77              7     9.0
# 4           1         Soda        77              7     9.0
# 5           1         Soda        77              7     9.0
# 6           1         Soda        77              7     9.0
# 7           1         Soda        77              7     9.0
# 8           1         Soda        77              7     9.0
# 9           1         Soda        77              7     9.0
# 10          0         Soda        77              7     9.0
# 11          1         Soda        77              7     9.0
# 12          1         Soda        77              7     9.0
# 13          1         Soda        77              7     9.0
# 14          1         Soda        77              7     9.0
#
#           price_range    busiest_days busiest_period_of_day  max_order
# 0   Mid range product  Regularly Busy        Average Orders         10
# 1   Mid range product      Least Busy        Average Orders         10
# 2   Mid range product      Least Busy           Most Orders         10
# 3   Mid range product      Least Busy        Average Orders         10
# 4   Mid range product      Least Busy           Most Orders         10
# 5   Mid range product  Regularly Busy        Average Orders         10
# 6   Mid range product     Busiest Day           Most Orders         10
# 7   Mid range product     Busiest Day           Most Orders         10
# 8   Mid range product     Busiest Day           Most Orders         10
# 9   Mid range product      Least Busy        Average Orders         10
# 10  Mid range product     Busiest Day           Most Orders         22
# 11  Mid range product  Regularly Busy           Most Orders         22
# 12  Mid range product  Regularly Busy           Most Orders         22
# 13  Mid range product     Busiest Day           Most Orders         22
# 14  Mid range product     Busiest Day           Most Orders         22

# %%
# To create a loyalty flag for each customer
df_trim.loc[df_trim['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_trim.loc[(df_trim['max_order'] <= 40) & (df_trim['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_trim.loc[df_trim['max_order'] <= 10, 'loyalty_flag'] = 'New customer'
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_4332\1411585422.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trim.loc[df_trim['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_trim['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
df_trim[['user_id','loyalty_flag','order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# # Creating a spending flag

# %%
# To group the average price of goods purchased by loyalty rating
df_trim.groupby('loyalty_flag').agg({'prices':['mean']})
# Out:
#                     prices
#                       mean
# loyalty_flag
# Loyal customer    7.773575
# New customer      7.801206
# Regular customer  7.798262

# %% [markdown]
# ### There appears to be an inverse relationship between customer loyalty and the average price spent by each loyalty group

# %%
# To create the spending flag
df_trim.loc[df_trim['prices']>=10,'spending_flag']='High spender'
df_trim.loc[df_trim['prices']<10,'spending_flag']='Low spender'
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_4332\2043308914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trim.loc[df_trim['prices']>=10,'spending_flag']='High spender'

# %%
df_trim['spending_flag'].value_counts(dropna=False)
# Out:
# Low spender     21760937
# High spender    10638795
# NaN                 5127
# Name: spending_flag, dtype: int64

# %%
df_trim[['user_id','prices','spending_flag','loyalty_flag']].head(15)
# Out:
#     user_id  prices spending_flag      loyalty_flag
# 0         1     9.0   Low spender      New customer
# 1         1     9.0   Low spender      New customer
# 2         1     9.0   Low spender      New customer
# 3         1     9.0   Low spender      New customer
# 4         1     9.0   Low spender      New customer
# 5         1     9.0   Low spender      New customer
# 6         1     9.0   Low spender      New customer
# 7         1     9.0   Low spender      New customer
# 8         1     9.0   Low spender      New customer
# 9         1     9.0   Low spender      New customer
# 10       15     9.0   Low spender  Regular customer
# 11       15     9.0   Low spender  Regular customer
# 12       15     9.0   Low spender  Regular customer
# 13       15     9.0   Low spender  Regular customer
# 14       15     9.0   Low spender  Regular customer

# %% [markdown]
# # Creating an order frequency flag

# %%
# To create a column with the aggreagate median of days_since_prior_order by user_id
df_trim['avg_days_since_last_order']=df_trim.groupby('user_id')['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_4332\3757540451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trim['avg_days_since_last_order']=df_trim.groupby('user_id')['days_since_prior_order'].transform(np.median)

# %%
# To create the order_frequency flag
df_trim.loc[df_trim['avg_days_since_last_order']>20,'order_frequency']='Non-frequent customer'
df_trim.loc[(df_trim['avg_days_since_last_order']>10)&(df_trim['avg_days_since_last_order']<=20),'order_frequency']='Regular customer'
df_trim.loc[df_trim['avg_days_since_last_order']<=10,'order_frequency']='Frequent customer'

# %%
df_trim['order_frequency'].value_counts(dropna=False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency, dtype: int64

# %%
df_trim.head(20)
# Out:
#     order_id  user_id  order_number  order_day_of_week  hour_order_placed  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
# 15   2293453       19             2                  5                 14
# 16   1973799       19             5                  6                 12
# 17    532817       19             7                  4                 17
# 18   1573906       21            10                  3                 10
# 19   1593000       31            10                  3                  8
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True         196                  1
# 1                     15.0         False         196                  1
# 2                     21.0         False         196                  1
# 3                     29.0         False         196                  1
# 4                     28.0         False         196                  1
# 5                     19.0         False         196                  1
# 6                     20.0         False         196                  1
# 7                     14.0         False         196                  2
# 8                      0.0         False         196                  4
# 9                     30.0         False         196                  1
# 10                     7.0         False         196                  2
# 11                     8.0         False         196                  6
# 12                     7.0         False         196                  1
# 13                     7.0         False         196                  1
# 14                    14.0         False         196                  1
# 15                     6.0         False         196                  3
# 16                     8.0         False         196                 15
# 17                     6.0         False         196                  1
# 18                     6.0         False         196                  2
# 19                     7.0         False         196                 17
#
#     reordered  ... department_id  prices        price_range    busiest_days  \
# 0           0  ...             7     9.0  Mid range product  Regularly Busy
# 1           1  ...             7     9.0  Mid range product      Least Busy
# 2           1  ...             7     9.0  Mid range product      Least Busy
# 3           1  ...             7     9.0  Mid range product      Least Busy
# 4           1  ...             7     9.0  Mid range product      Least Busy
# 5           1  ...             7     9.0  Mid range product  Regularly Busy
# 6           1  ...             7     9.0  Mid range product     Busiest Day
# 7           1  ...             7     9.0  Mid range product     Busiest Day
# 8           1  ...             7     9.0  Mid range product     Busiest Day
# 9           1  ...             7     9.0  Mid range product      Least Busy
# 10          0  ...             7     9.0  Mid range product     Busiest Day
# 11          1  ...             7     9.0  Mid range product  Regularly Busy
# 12          1  ...             7     9.0  Mid range product  Regularly Busy
# 13          1  ...             7     9.0  Mid range product     Busiest Day
# 14          1  ...             7     9.0  Mid range product     Busiest Day
# 15          0  ...             7     9.0  Mid range product  Regularly Busy
# 16          1  ...             7     9.0  Mid range product  Regularly Busy
# 17          1  ...             7     9.0  Mid range product      Least Busy
# 18          0  ...             7     9.0  Mid range product      Least Busy
# 19          0  ...             7     9.0  Mid range product      Least Busy
#
#    busiest_period_of_day max_order      loyalty_flag  spending_flag  \
# 0         Average Orders        10      New customer    Low spender
# 1         Average Orders        10      New customer    Low spender
# 2            Most Orders        10      New customer    Low spender
# 3         Average Orders        10      New customer    Low spender
# 4            Most Orders        10      New customer    Low spender
# 5         Average Orders        10      New customer    Low spender
# 6            Most Orders        10      New customer    Low spender
# 7            Most Orders        10      New customer    Low spender
# 8            Most Orders        10      New customer    Low spender
# 9         Average Orders        10      New customer    Low spender
# 10           Most Orders        22  Regular customer    Low spender
# 11           Most Orders        22  Regular customer    Low spender
# 12           Most Orders        22  Regular customer    Low spender
# 13           Most Orders        22  Regular customer    Low spender
# 14           Most Orders        22  Regular customer    Low spender
# 15           Most Orders         9      New customer    Low spender
# 16           Most Orders         9      New customer    Low spender
# 17        Average Orders         9      New customer    Low spender
# 18           Most Orders        33  Regular customer    Low spender
# 19        Average Orders        20  Regular customer    Low spender
#
#    avg_days_since_last_order        order_frequency
# 0                       20.5  Non-frequent customer
# 1                       20.5  Non-frequent customer
# 2                       20.5  Non-frequent customer
# 3                       20.5  Non-frequent customer
# 4                       20.5  Non-frequent customer
# 5                       20.5  Non-frequent customer
# 6                       20.5  Non-frequent customer
# 7                       20.5  Non-frequent customer
# 8                       20.5  Non-frequent customer
# 9                       20.5  Non-frequent customer
# 10                      10.0      Frequent customer
# 11                      10.0      Frequent customer
# 12                      10.0      Frequent customer
# 13                      10.0      Frequent customer
# 14                      10.0      Frequent customer
# 15                       6.0      Frequent customer
# 16                       6.0      Frequent customer
# 17                       6.0      Frequent customer
# 18                       7.5      Frequent customer
# 19                       6.0      Frequent customer
#
# [20 rows x 22 columns]

# %% [markdown]
# ## Crosstabulations

# %%
# To crosstabulate loyalty_flag with spending_flag
crosstab_loyalty_spending=pd.crosstab(df_trim['loyalty_flag'],df_trim['spending_flag'],dropna=False)

# %%
crosstab_loyalty_spending
# Out:
# spending_flag     High spender  Low spender
# loyalty_flag
# Loyal customer         3351872      6930891
# New customer           2062155      4180686
# Regular customer       5224768     10649360

# %%
crosstab_loyalty_spending.to_clipboard()

# %%
# To crosstabulate loyalty_flag with order_frequency
crosstab_loyalty_frequency=pd.crosstab(df_trim['loyalty_flag'],df_trim['order_frequency'],dropna=False)

# %%
crosstab_loyalty_frequency
# Out:
# order_frequency   Frequent customer  Non-frequent customer  Regular customer
# loyalty_flag
# Loyal customer             10279960                      0              4133
# New customer                1648671                2724962           1870352
# Regular customer            9631222                 911475           5334079

# %%
crosstab_loyalty_frequency.to_clipboard()

# %% [markdown]
# # Exporting the dataframe

# %%
df_trim.to_pickle(os.path.join(path,'Data','Prepared Data','11-13_orders_products_merged.pkl'))
